# %%
import os
import platform
from pathlib import Path

def list_desktop_files():
    desktop = Path.home() / "Desktop"
    if not desktop.exists():
        print("Desktop path not found.")
        return
    files = os.listdir(desktop)
    print("Files and folders on Desktop:")
    for (f in files):
        print(" -", f)

def create_file():
    name = input("Enter the file name (with extension, e.g., file.txt): ")
    with open(name, "w") as f:
        f.write("This is a sample file created by automation.")
    print(f"File '{name}' created successfully.")

def create_folder():
    folder_name = input("Enter folder name to create: ")
    os.makedirs(folder_name, exist_ok=True)
    print(f"Folder '{folder_name}' created successfully.")

def message_friend():
    # This is a placeholder. In a real scenarion, WhatsApp API, etc.
    friend = input("Enter your friend's name: ")
    message = input("Enter your message: ")
    print(f"Sending message to {friend}...\nMessage: {message}")
    print("Message sent! (This is a mock implementation)")

def shutdown_computer():
    print("Shutting down in 10 seconds. Press Ctrl+C to cancel.")
    time.sleep(10)
    if platform.system() == "Windows":
        os.system("shutdown /s /t 1")
    elif platform.system() == "Linux" or platform.system() == "Darwin":
        os.system("shutdown now")
    else:
        print("Shutdown command not supported on this OS.")

def main():
    print("""
Choose an option:
1 = Show files on Desktop
2 = Create a file
3 = Create a folder
4 = Message a friend
5 = Shutdown the computer""")
    choice = input("Enter your choice: ")
    
    if choice == "1":
        list_desktop_files()
    elif choice == "2":
        create_file()
    elif choice == "3":
        create_folder()
    elif choice == "4":
        message_friend()
    elif choice == "5":
        shutdown_computer()
    else:
        print("Invalid choice!")

if __name__ == "__main__":
    main()
